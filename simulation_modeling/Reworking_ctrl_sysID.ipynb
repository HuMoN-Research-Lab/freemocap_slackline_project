# %% [markdown]
# # Model Fit with Least Squares
#
# Let's first just simulate a cartpole, and fit back to that (with noise) to see if everything checks out.

# %% [markdown]
# ### Equations of motion:
#
# $$
# \begin{align*}\left[ \begin{array}{cc}
# m_c + m_p & m_p \ell_p\sin(\theta) \\
# m_p \ell_p \sin(\theta) & m_p \ell_p^2
# \end{array} \right]
# \left[ \begin{array}{c}
# \ddot{x} \\ \ddot{\theta}
# \end{array}\right]
# +
# \left[\begin{array}{c}
# m_p \ell_p \cos(\theta) \dot{\theta}^2 \\ - m_p g \ell_p \sin(\theta)
# \end{array}\right]
# =
# \left[\begin{array}{c}
# -k_c x \\
# 0
# \end{array}\right]\end{align*}
# $$
# So let's set up functions for this.

# %%
import numpy as np

def mass_matrix(params, x):
    M = np.zeros((2, 2))
    M[0, 0] = params["mass_cart"] + params["mass_pendulum"]
    M[0, 1] = params["mass_pendulum"] * params["length_pendulum"] * np.sin(x[1])
    M[1, 0] = params["mass_pendulum"] * params["length_pendulum"] * np.sin(x[1])
    M[1, 1] = params["mass_pendulum"] * params["length_pendulum"]**2
    return M


def coriolis(params, x, qDot=None):
    # hacky: we're assuming x input if qDot is None, and (q, qDot) otherwise.
    C = np.zeros(2)
    if qDot is None:
        C[0] = params["mass_pendulum"] * params["length_pendulum"] * np.cos(x[1]) * x[3] ** 2
        C[1] = - params["mass_pendulum"] * params["gravity"] * params["length_pendulum"] * np.sin(x[1])
    else:
        C[0] = params["mass_pendulum"] * params["length_pendulum"] * np.cos(x[1]) * qDot[1] ** 2
        C[1] = - params["mass_pendulum"] * params["gravity"] * params["length_pendulum"] * np.sin(x[1])
    return C

def forces(params, x):
    F = np.zeros(2)
    F[0] = - params["spring_cart"] * x[0]
    return F

# %% [markdown]
# Let's do a simple simulation and plot it

# %%
import matplotlib.pyplot as plt

def euler_forward(params, x):
    M = mass_matrix(params, x)
    C = coriolis(params, x)
    F = forces(params, x)
    acceleration = np.linalg.lstsq(M, F - C, rcond=None)[0]
    # or 
    # acceleration = np.matmul(np.linalg.pinv(M), (F - C))
    return x + np.concatenate((x[2:], acceleration))*dt

x = np.array([0, 0, 0, 0.1])

params = {"mass_cart": 1, # mass pendulum * 0.14, kg, based on estimates here https://exrx.net/Kinesiology/Segments
          "mass_pendulum": 72.6, # appoximate weight, kg
          "length_pendulum": 1.206, # mean from data, m
          "spring_cart": 1,
          "gravity": 9.81}

dt = 0.001  # the euler foward does not seem to like using the actual video framerate
sim_time = 10

timesteps = int(sim_time/dt)

x_trajectory = np.zeros((timesteps, 4))

for i in range(timesteps):
    x = euler_forward(params, x)
    x_trajectory[i, :] = x

plt.figure(1)
plt.plot(x_trajectory[:, 0], x_trajectory[:, 2])
plt.scatter(x_trajectory[0, 0], x_trajectory[0, 2], c="r")
plt.xlabel("cart position")
plt.ylabel("cart velocity")
plt.figure(2)
plt.plot(x_trajectory[:, 1], x_trajectory[:, 3])
plt.scatter(x_trajectory[0, 1], x_trajectory[0, 3], c="r")
plt.xlabel("pole position")
plt.ylabel("pole velocity")
plt.show()

# %% [markdown]
# The above uses a simplistic Euler Forward method to solve the differential equation, which could be why we were seeing errors related to energy. Below we implement an RK4 solver to see how it does.

# %%
# try it with an rk4 solver

def dxdt(t, x, params):
    M = mass_matrix(params, x)
    C = coriolis(params, x)
    F = forces(params, x)
    acceleration = np.linalg.lstsq(M, F - C, rcond=None)[0]
    # or
    # acceleration = np.matmul(np.linalg.pinv(M), (F - C))
    return np.concatenate((x[2:], acceleration))

def rk4(f, y0, t, *args):
    dt = t[1] - t[0]
    y = [y0]
    
    for i in range(1, len(t)):
        ti = t[i - 1]
        yi = y[-1]
        
        k1 = f(ti, yi, *args)
        k2 = f(ti + dt / 2, yi + dt * k1 / 2, *args)
        k3 = f(ti + dt / 2, yi + dt * k2 / 2, *args)
        k4 = f(ti + dt, yi + dt * k3, *args)
        
        y_new = yi + (dt / 6) * (k1 + 2 * k2 + 2 * k3 + k4)
        y.append(y_new)
    
    return y

x = np.array([0, 0, 0, 0.1])

params = {"mass_cart": 1, # mass pendulum * 0.014, kg, based on estimates here https://exrx.net/Kinesiology/Segments
          "mass_pendulum": 72.6, # appoximate weight, kg
          "length_pendulum": 1.206, # mean from data, m
          "spring_cart": 1,
          "gravity": 9.81}

frame_rate = 60 # fps
dt = 0.01667
sim_time = 10

timesteps = int(sim_time/dt)
t = np.linspace(0, sim_time, timesteps)

x_trajectory = np.array(rk4(dxdt, x, t, params))

plt.figure(1)
plt.plot(x_trajectory[:, 0], x_trajectory[:, 2])
plt.scatter(x_trajectory[0, 0], x_trajectory[0, 2], c="r")
plt.xlabel("cart position")
plt.ylabel("cart velocity")
plt.figure(2)
plt.plot(x_trajectory[:, 1], x_trajectory[:, 3])
plt.scatter(x_trajectory[0, 1], x_trajectory[0, 3], c="r")
plt.xlabel("pole position")
plt.ylabel("pole velocity")
plt.show()

# %% [markdown]
# Already we see a big difference in the pole position plot which looks promising.

# %% [markdown]
# Let's do a little sanity check. The total energy should stay constant, since it's a conservative system.

# %%
def potential_energy(params, x):
    spring_energy = 0.5 * params["spring_cart"] * x[0]**2
    gravitational_energy = (params["mass_pendulum"] * params["gravity"]
                            * params["length_pendulum"] * np.cos(x[1]))
    return spring_energy + gravitational_energy

def kinetic_energy(params, x):
    cart_energy = params["mass_cart"]/2. * x[2]**2
    pendulum_energy = (params["mass_pendulum"]/2.
                       * ((params["length_pendulum"] * x[3])**2
                          + x[2]**2
                          + 2*params["length_pendulum"]*x[2]*x[3]*np.sin(x[1])))
    return cart_energy + pendulum_energy

potential = np.zeros(timesteps)
kinetic = np.zeros(timesteps)
for i in range(timesteps):
    potential[i] = potential_energy(params, x_trajectory[i, :])
    kinetic[i] = kinetic_energy(params, x_trajectory[i, :])

energy_traj = potential + kinetic
plt.figure(1)
plt.plot(energy_traj)
plt.xlabel('timesteps')
plt.ylabel('Energy [joules]')
plt.title('Total energy')
plt.figure(2)
plt.plot(potential)
plt.plot(kinetic)
plt.xlabel('timesteps')
plt.ylabel('Energy [joules]')
plt.legend(['potential energy', 'kinetic energy'])
(energy_traj[0] - energy_traj[-1])/energy_traj.mean()
# Out:
# 1.61128838667637

# %% [markdown]
# RK4 is still not perfect, but at 10 orders of magnitude less energy its a lot better than forward Euler.

# %% [markdown]
# ## Fitting a feedback controller
# Let's assume we know (roughly) the system parameters, in addition to having a recording of the states. But we don't know the feedback controller. Let's try to fit a linear state-feedback controller of the form:
#
# $$
# F(q, \dot{q}) = K \cdot
# \left[\begin{array}{c}
# q \\
# \dot{q}
# \end{array}\right]
# $$
#
# where $K$ is a feedback matrix.

# %% [markdown]
# For our cartpole, assuming we still have only control at the base (and instead of the spring). So we have
#
# $$
# \begin{align*}\left[ \begin{array}{cc}
# m_c + m_p & m_p \ell_p\sin(\theta) \\
# m_p \ell_p \sin(\theta) & m_p \ell_p^2
# \end{array} \right]
# \left[ \begin{array}{c}
# \ddot{x} \\ \ddot{\theta}
# \end{array}\right]
# +
# \left[\begin{array}{c}
# m_p \ell_p \cos(\theta) \dot{\theta}^2 \\ - m_p g \ell_p \sin(\theta)
# \end{array}\right]
# & =
# K \cdot
# \left[\begin{array}{c}
# q \\
# \dot{q}
# \end{array}\right] \\
# & =
# \left[\begin{array}{cccc}
# k_{11} & k_{12} & k_{13} & k_{14} \\
# k_{21} & k_{22} & k_{23} & k_{24}
# \end{array}\right]
# \cdot
# \left[\begin{array}{c}
# x \\ \theta \\
# \dot{x} \\ \dot{\theta}
# \end{array}\right]
# \\
# & =
# \left[\begin{array}{cccc}
# k_{11} & k_{12} & k_{13} & k_{14} \\
# 0 & 0 & 0 & 0
# \end{array}\right]
# \cdot
# \left[\begin{array}{c}
# x \\ \theta \\
# \dot{x} \\ \dot{\theta}
# \end{array}\right]
# \end{align*}
# $$

# %% [markdown]
# Note we've set $k_{21} = k_{22} = k_{23} = k_{24} = 0$ since we want to ID a model that only has actuation at the cart (not on the pole).
# So we'll only need to solve for the first row.
# We also need to put htis in `A@x = b` form, to solve the least-squares problem, where `x` are the parameters we're solving for, that is $k_{11}, k_{12}, k_{13}, k_{14}$. Here `b` would be our dynamics (but just the $\ddot{x}$ part), and `A` would be the kinematics.

# %%
n_samples = 100
accelerations = np.diff(x_trajectory[:, 2:], axis=0)/dt
q = x_trajectory[:n_samples, :2]
qDot = x_trajectory[:n_samples, 2:]
qDotDot = accelerations[:n_samples, :]

def inertial_and_coriolis_forces(params, q, qDot, qDotDot):
    f = mass_matrix(params, q)@qDotDot + coriolis(params, q, qDot)
    return np.atleast_2d(f).T

num_datapoints = q.shape[0]
b = np.zeros((num_datapoints, 1))
A = np.zeros((num_datapoints, 4))
for index in range(num_datapoints):
    A[index, :] = np.concatenate((q[index, :], qDot[index, :]))
    b[index, :] = inertial_and_coriolis_forces(params, q[index, :], qDot[index, :], qDotDot[index, :])[0, 0]

K, residuals, rank, singular_values = np.linalg.lstsq(A, b, rcond=None)

print(f"Feedback gains: {K.T}")
print(f"residuals: {residuals}")
print(f"rank: {rank}")
print(f"singular_values: {singular_values}")
# Out:
# Feedback gains: [[-2.14632719e+01  2.43761073e-01  1.20631003e+01  5.36125535e-04]]
# residuals: [5.26335708e-05]
# rank: 4
# singular_values: [2.72282075e+00 1.80825798e-01 7.25361212e-02 5.37372069e-04]

# %%
# Get the real kinematics:
state_information = np.load('/Users/philipqueen/Documents/Humon Research Lab/FreeMocap_Data/4stepsequence_session2_10_5_22/state_information.npy', allow_pickle=True)

# The state information is formatted [BOS location, BOS velocity, COM location, COM velocity, angle, angular velocity] 
print(f"state information shape: {state_information.shape}")

# We want it formatted [BOS location, angle, BOS velocity, angular velocity]
print(f"shape of simulated kinematics: {A.shape}")

starting_frame = 2400
frame_duration = A.shape[0]

A_real_kinematics = state_information[starting_frame:starting_frame+frame_duration, [0, 4, 1, 5]]

print(f"shape of extracted frames: {A_real_kinematics.shape}")
# Out:
# state information shape: (7415, 6)
# shape of simulated kinematics: (100, 4)
# shape of extracted frames: (100, 4)

# %%
# Try fitting real kinematics
n_samples = 100
accelerations = np.diff(x_trajectory[:, 2:], axis=0)/dt
q = x_trajectory[:n_samples, :2]
qDot = x_trajectory[:n_samples, 2:]
qDotDot = accelerations[:n_samples, :]

def inertial_and_coriolis_forces(params, q, qDot, qDotDot):
    f = mass_matrix(params, q)@qDotDot + coriolis(params, q, qDot)
    return np.atleast_2d(f).T

num_datapoints = q.shape[0]
b = np.zeros((num_datapoints, 1))
A = A_real_kinematics
for index in range(num_datapoints):
    b[index, :] = inertial_and_coriolis_forces(params, q[index, :], qDot[index, :], qDotDot[index, :])[0, 0]

K, residuals, rank, singular_values = np.linalg.lstsq(A, b, rcond=None)

print(f"Feedback gains: {K.T}")
print(f"residuals: {residuals}")
print(f"rank: {rank}")
print(f"singular_values: {singular_values}")
# Out:
# Feedback gains: [[-1.42639413e-03 -1.22144880e-01  5.22767927e-02  1.73598508e+00]]
# residuals: [5.09728575]
# rank: 4
# singular_values: [1.09951679e+03 4.93270441e+01 1.24525610e+01 6.64719084e-01]

# %% [markdown]
# Fitting the real kinematics doesn't yield a very similar result, but that's to be expected for now. After all, the real slackliner isn't driving the cart, they're moving the pendulum. The hope is that the more complex, pendulum driven model fits better with the real kinematics.

# %% [markdown]
# Let's try using incorrect estimates for parameters, specifically we'll try the high and low ranges of pendulum values from the data.

# %%
wrong_params = {"mass_cart": 1,
                "mass_pendulum": 72.6,
                "length_pendulum": 1.178, #low range of pendulum lengths from session
                "gravity": 9.81}

b2 = np.zeros((num_datapoints, 1))
A2 = np.zeros((num_datapoints, 4))
for index in range(num_datapoints):
    A2[index, :] = np.concatenate((q[index, :],
                                        qDot[index, :]))
    b2[index, :] = inertial_and_coriolis_forces(wrong_params, q[index, :], qDot[index, :], qDotDot[index, :])[0, 0]

K2, residuals2, rank2, singular_values2 = np.linalg.lstsq(A2, b2, rcond=None)

print(f"Feedback gains: {K2.T}")
# Out:
# Feedback gains: [[-17.10906058   0.92008829  21.59033809  -0.18235843]]

# %%
wrong_params = {"mass_cart": 1,
                "mass_pendulum": 72.6,
                "length_pendulum": 1.228, #high range of pendulum lengths from session
                "gravity": 9.81}

b2 = np.zeros((num_datapoints, 1))
A2 = np.zeros((num_datapoints, 4))
for index in range(num_datapoints):
    A2[index, :] = np.concatenate((q[index, :],
                                        qDot[index, :]))
    b2[index, :] = inertial_and_coriolis_forces(wrong_params, q[index, :], qDot[index, :], qDotDot[index, :])[0, 0]

K2, residuals2, rank2, singular_values2 = np.linalg.lstsq(A2, b2, rcond=None)

print(f"Feedback gains: {K2.T}")
# Out:
# Feedback gains: [[-24.88443801  -0.28763888   4.57741349   0.14423899]]

# %% [markdown]
# There's still quite some variability, particularly it seems a little more sensitive to the lower values than the higher values. That may be because the lower value is lower relative to the mean, or that shortening the pendulum has more of an effect on the dynamics than lengthening it. Adding more length to the pendulum seems to indicate it is more sensitive to the shortening pendulum.

# %% [markdown]
# Now let's try it again, but allow for control at both the cart and the pole, but on the same data.
# We'll now want to solve for that second row as well, which means we'll need to double-stack our data, like this:
#
# $$
# \begin{align*}\left[ \begin{array}{cc}
# m_c + m_p & m_p \ell_p\sin(\theta) \\
# m_p \ell_p \sin(\theta) & m_p \ell_p^2
# \end{array} \right]
# \left[ \begin{array}{c}
# \ddot{x} \\ \ddot{\theta}
# \end{array}\right]
# +
# \left[\begin{array}{c}
# m_p \ell_p \cos(\theta) \dot{\theta}^2 \\ - m_p g \ell_p \sin(\theta)
# \end{array}\right]
# & =
# K \cdot
# \left[\begin{array}{c}
# q \\
# \dot{q}
# \end{array}\right] \\
# & =
# \left[\begin{array}{cccccccc}
# x & \theta & \dot{x} & \dot{\theta} & 0 & 0 & 0 & 0 \\
#  0 & 0 & 0 & 0 & x & \theta & \dot{x} & \dot{\theta}
#  \end{array}\right]
#  \cdot
#  \left[\begin{array}{c}
# k_{11} \\
# k_{12} \\
# k_{13} \\
# k_{14} \\
# k_{21} \\
# k_{22} \\
# k_{23} \\
# k_{24}
# \end{array}\right]
# \end{align*}
# $$

# %%
b3 = np.zeros((2*num_datapoints, 1))
A3 = np.zeros((2*num_datapoints, 8))

for index in range(num_datapoints):
    A3[2*index, :4] = np.concatenate((q[index, :], qDot[index, :]))
    A3[2*index+1, 4:] = np.concatenate((q[index, :], qDot[index, :]))
    b3[2*index:2*index+2, :] = inertial_and_coriolis_forces(params, q[index, :], qDot[index, :], qDotDot[index, :])

K3, residuals3, rank3, singular_values3 = np.linalg.lstsq(A3, b3, rcond=None)

print(f"Feedback gains: {K3.T}")
# Out:
# Feedback gains: [[-2.14632719e+01  2.43761073e-01  1.20631003e+01  5.36125535e-04
#    3.09144110e+01  7.53155098e-01 -6.81238156e+00  3.57072355e+00]]

# %% [markdown]
# Okay good, so it correctly puts all the responsibility into the cart force.
